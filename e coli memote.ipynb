# %% [markdown]
# # Ecoli Memote - Model evaluation

# %% [markdown]
# We will try to evaluate different models based on the memote function

# %%
import numpy as np
from cobra.io import read_sbml_model

# %%
model_glutamicum = read_sbml_model('seed_Seed196627_4.COBRA-sbml3.xml')

# %%
model_ecoli_iML1515 = read_sbml_model('iML1515.xml.gz')

# %%
#Memote reports for Corynebacterium

# %%
# %%time
# !memote report snapshot --skip test_stoichiometric_consistency \
    --skip test_find_metabolites_not_produced_with_open_bounds \
    --skip test_find_metabolites_not_consumed_with_open_bounds seed_Seed196627_4.COBRA-sbml3.xml --filename model_glutamicum.html
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.6.12, pytest-6.1.2, py-1.9.0, pluggy-0.13.1
# rootdir: /usr/local/lib/python3.6/dist-packages/memote/suite/tests
# collected 146 items / 1 skipped / 145 selected
#
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_annotation.py . [  0%]
# .FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF..FF.F.FF......FFF.F.FFFFFFFFF.         [ 44%]
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_basic.py . [ 45%]
# .....F..........F.F.FF                                                   [ 60%]
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_biomass.py . [ 60%]
# FFFFFFFFF                                                                [ 67%]
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_consistency.py s [ 67%]
# FFssssssssssssssssFFFFFF.ssF                                             [ 86%]
# ...

# %%
#Memote reports for iML1515

# %%
# %%time
# !memote report snapshot --skip test_stoichiometric_consistency \
    --skip test_find_metabolites_not_produced_with_open_bounds \
    --skip test_find_metabolites_not_consumed_with_open_bounds iML1515.xml.gz --filename iML1515.html
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.6.12, pytest-6.1.2, py-1.9.0, pluggy-0.13.1
# rootdir: /usr/local/lib/python3.6/dist-packages/memote/suite/tests
# collected 155 items / 1 skipped / 154 selected
#
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_annotation.py . [  0%]
# ..FFFFFFFFF.FFFFF.FFFFFFFFFFFFFFF..FF..F...F....FFF.F..FF.FFF...         [ 41%]
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_basic.py . [ 42%]
# .....F............F.FF                                                   [ 56%]
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_biomass.py . [ 57%]
# ..F...F.....FF..FF                                                       [ 69%]
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_consistency.py s [ 69%]
# ..ssssssssssssssss.FFFFF.ssF                                             [ 87%]
# ...

# %%
# Evaluation of EcoliC 1368

# %%
# %%time
# !memote report snapshot --skip test_stoichiometric_consistency \
    --skip test_find_metabolites_not_produced_with_open_bounds \
    --skip test_find_metabolites_not_consumed_with_open_bounds iEcolC_1368.xml --filename Ecoli1368.html
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.6.12, pytest-6.1.2, py-1.9.0, pluggy-0.13.1
# rootdir: /usr/local/lib/python3.6/dist-packages/memote/suite/tests
# collected 155 items / 1 skipped / 154 selected
#
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_annotation.py . [  0%]
# ..FFFFFFFF..FFFFF.FFFFFFFFFFFFFFF..FF..F...F....FFF.FFFFFFFFFF..         [ 41%]
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_basic.py . [ 42%]
# .....F............F.FF                                                   [ 56%]
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_biomass.py . [ 57%]
# ..F...F.....FF..FF                                                       [ 69%]
# ../../../usr/local/lib/python3.6/dist-packages/memote/suite/tests/test_consistency.py s [ 69%]
# FFssssssssssssssssFFFFFF.ssF                                             [ 87%]
# ...
